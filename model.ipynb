# %%
pip install tensorflow matplotlib scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
#    ---------------------------------------- 0/2 [et-xmlfile]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
pip install --upgrade torch torchvision
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/113.8 MB ? eta -:--:--
#     --------------------------------------- 1.8/113.8 MB 9.8 MB/s eta 0:00:12
#    - -------------------------------------- 3.7/113.8 MB 9.6 MB/s eta 0:00:12
#    -- ------------------------------------- 5.8/113.8 MB 9.6 MB/s eta 0:00:12
#    -- ------------------------------------- 7.6/113.8 MB 9.6 MB/s eta 0:00:12
#    -- ------------------------------------- 8.1/113.8 MB 8.2 MB/s eta 0:00:13
#    --- ------------------------------------ 8.7/113.8 MB 7.1 MB/s eta 0:00:15
#    --- ------------------------------------ 10.7/113.8 MB 7.4 MB/s eta 0:00:14
#    ---- ----------------------------------- 12.6/113.8 MB 7.6 MB/s eta 0:00:14
#    ----- ---------------------------------- 14.4/113.8 MB 7.8 MB/s eta 0:00:13
#    ----- ---------------------------------- 16.3/113.8 MB 7.8 MB/s eta 0:00:13
# ...

# %%
pip install --upgrade torch torchvision --index-url https://download.pytorch.org/whl/cpu
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://download.pytorch.org/whl/cpu
# ...
#    ---------------------------------------- 0.0/113.7 MB ? eta -:--:--
#    ---------------------------------------- 0.5/113.7 MB 2.9 MB/s eta 0:00:39
#     --------------------------------------- 2.1/113.7 MB 6.0 MB/s eta 0:00:19
#    - -------------------------------------- 3.9/113.7 MB 6.8 MB/s eta 0:00:17
#    -- ------------------------------------- 5.8/113.7 MB 7.5 MB/s eta 0:00:15
#    -- ------------------------------------- 7.3/113.7 MB 7.5 MB/s eta 0:00:15
#    --- ------------------------------------ 9.4/113.7 MB 7.7 MB/s eta 0:00:14
#    --- ------------------------------------ 11.0/113.7 MB 7.9 MB/s eta 0:00:13
#    ---- ----------------------------------- 12.8/113.7 MB 7.9 MB/s eta 0:00:13
#    ----- ---------------------------------- 14.9/113.7 MB 8.1 MB/s eta 0:00:13
# ...

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split
# Out:
# C:\Users\tirth\AppData\Roaming\Python\Python313\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/attr_value.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\tirth\AppData\Roaming\Python\Python313\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# ...

# %%
import os
import pandas as pd
from PIL import Image
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from torchvision.models import resnet18, ResNet18_Weights
import torch.nn as nn
import torch.optim as optim

# =========================
# 1️⃣ Paths
# =========================
data_dir = r"C:\Users\tirth\OneDrive\Desktop\Data analysis\Project\accident\dataset"
csv_file = r"C:\Users\tirth\OneDrive\Desktop\Data analysis\Project\accident\dataset_database.csv"

# %%
# =========================
# 2️⃣ Transformations
# =========================
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # ResNet input size
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

# %%
# =========================
# 3️⃣ Custom Dataset
# =========================
class AccidentDataset(Dataset):
    def __init__(self, csv_file, img_dir, transform=None):
        self.data = pd.read_csv(csv_file)
        self.img_dir = img_dir
        self.transform = transform

        # Map labels: n = 0 (No Accident), y = 1 (Accident)
        self.label_map = {'n': 0, 'y': 1}

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        # ✅ FIX HERE
        img_name = self.data.iloc[idx]['subject']
        label = self.data.iloc[idx]['collision']

        img_path = os.path.join(self.img_dir, img_name)
        image = Image.open(img_path).convert("RGB")

        if self.transform:
            image = self.transform(image)

        label = self.label_map[label]
        return image, label

# %%
# =========================
# 4️⃣ Load dataset and split
# =========================
dataset = AccidentDataset(csv_file, data_dir, transform=transform)

train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)

# %%
# =========================
# 5️⃣ Model Setup
# =========================
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load ResNet18 pretrained model
model = resnet18(weights=ResNet18_Weights.DEFAULT)
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 2)  # 2 classes
model = model.to(device)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
pip install tqdm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from tqdm import tqdm

num_epochs = 10

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    # Progress bar per epoch
    progress_bar = tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs}")

    for images, labels in progress_bar:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        # Live metrics
        train_acc = 100 * correct / total
        avg_loss = running_loss / (progress_bar.n 
        progress_bar.set_postfix({
            "Loss": f"{avg_loss:.4f}",
            "Acc(%)": f"{train_acc:.2f}"
        })

    print(f"✅ Epoch {epoch+1} completed | Loss: {avg_loss:.4f} | Accuracy: {train_acc:.2f}%\n")
# Out:
# Epoch 1/10: 100%|██████████| 500/500 [25:41<00:00,  3.08s/it, Loss=0.4712, Acc(%)=80.56]
# ✅ Epoch 1 completed | Loss: 0.4712 | Accuracy: 80.56%
# Epoch 2/10: 100%|██████████| 500/500 [2:00:49<00:00, 14.50s/it, Loss=0.4395, Acc(%)=81.53]
# ✅ Epoch 2 completed | Loss: 0.4395 | Accuracy: 81.53%
# Epoch 3/10: 100%|██████████| 500/500 [32:44<00:00,  3.93s/it, Loss=0.4171, Acc(%)=81.84]
# ✅ Epoch 3 completed | Loss: 0.4171 | Accuracy: 81.84%
# Epoch 4/10: 100%|██████████| 500/500 [22:29<00:00,  2.70s/it, Loss=0.4068, Acc(%)=82.29]
# ✅ Epoch 4 completed | Loss: 0.4068 | Accuracy: 82.29%
# Epoch 5/10: 100%|██████████| 500/500 [20:56<00:00,  2.51s/it, Loss=0.3929, Acc(%)=82.06]
# ✅ Epoch 5 completed | Loss: 0.3929 | Accuracy: 82.06%
# Epoch 6/10: 100%|██████████| 500/500 [21:19<00:00,  2.56s/it, Loss=0.3866, Acc(%)=82.59]
# ✅ Epoch 6 completed | Loss: 0.3866 | Accuracy: 82.59%
# Epoch 7/10: 100%|██████████| 500/500 [22:11<00:00,  2.66s/it, Loss=0.3764, Acc(%)=82.85]
# ...

# %%
import pandas as pd

df = pd.read_csv(csv_file)
print(df.columns)
print(df.head())
# Out:
# Index(['subject', 'collision'], dtype='object')
#      subject collision
# 0  00001.jpg         n
# 1  00002.jpg         n
# 2  00003.jpg         n
# 3  00004.jpg         n
# 4  00005.jpg         n

# %%
import pickle
import os

print("Current working directory:", os.getcwd())

with open("accident_resnet18.pkl", "wb") as f:
    pickle.dump(model.state_dict(), f)

print("✅ Model saved as accident_resnet18.pkl")
# Out:
# Current working directory: c:\Users\tirth\OneDrive\Desktop\Data analysis\Project\accident
# ✅ Model saved as accident_resnet18.pkl

# %%
import pickle
import torch
import torch.nn as nn
from torchvision.models import resnet18, ResNet18_Weights

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Recreate model architecture
model = resnet18(weights=ResNet18_Weights.DEFAULT)
model.fc = nn.Linear(model.fc.in_features, 2)

# Load weights
with open("accident_resnet18.pkl", "rb") as f:
    model.load_state_dict(pickle.load(f))

model = model.to(device)
model.eval()

print("✅ Pickle model loaded successfully")
# Out:
# ✅ Pickle model loaded successfully

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

# %%
def predict_accident(image_path):
    image = Image.open(image_path).convert("RGB")
    image = transform(image).unsqueeze(0)  # Add batch dimension
    image = image.to(device)

    with torch.no_grad():
        outputs = model(image)
        _, predicted = torch.max(outputs, 1)

    class_names = ["No Accident", "Accident"]
    return class_names[predicted.item()]

# %%
test_image = r"C:\Users\tirth\OneDrive\Desktop\Data analysis\Project\accident\dataset\00001.jpg"

result = predict_accident(test_image)
print("🚦 Prediction:", result)
# Out:
# 🚦 Prediction: No Accident

# %%
import torch.nn.functional as F

def predict_with_confidence(image_path):
    image = Image.open(image_path).convert("RGB")
    image = transform(image).unsqueeze(0).to(device)

    with torch.no_grad():
        outputs = model(image)
        probs = F.softmax(outputs, dim=1)

    class_names = ["No Accident", "Accident"]
    confidence, predicted = torch.max(probs, 1)

    return class_names[predicted.item()], confidence.item() * 100

# %%
label, conf = predict_with_confidence(test_image)
print(f"🚦 Prediction: {label} ({conf:.2f}%)")
# Out:
# 🚦 Prediction: No Accident (61.87%)

# %%
csv_file = r"C:\Users\tirth\OneDrive\Desktop\Data analysis\Project\accident\dataset_database.csv"
df = pd.read_csv(csv_file)
df.shape
# Out:
# (10000, 2)
